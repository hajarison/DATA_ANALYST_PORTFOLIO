# %% [markdown]
# # Régression de Keras

# %% [markdown]
# ### Importation des packages et données

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
# lecture de données à partir d'un URL
url = 'https://raw.githubusercontent.com/moncoachdata/DATA_DEEP_LEARNING/master/kc_house_data.csv'
df = pd.read_csv(url)

# %% [markdown]
# ## Exploration de données

# %%
df.head(5) # Visualisation des 5 premiers données
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     21597 non-null  int64
#  9   view           21597 non-null  int64
#  10  condition      21597 non-null  int64
#  11  grade          21597 non-null  int64
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  int64
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   21597 non-null  int64
#  16  zipcode        21597 non-null  int64
# ...

# %%
df.describe().transpose() # Description des données
# Out:
#                  count          mean           std           min  \
# id             21597.0  4.580474e+09  2.876736e+09  1.000102e+06
# price          21597.0  5.402966e+05  3.673681e+05  7.800000e+04
# bedrooms       21597.0  3.373200e+00  9.262989e-01  1.000000e+00
# bathrooms      21597.0  2.115826e+00  7.689843e-01  5.000000e-01
# sqft_living    21597.0  2.080322e+03  9.181061e+02  3.700000e+02
# sqft_lot       21597.0  1.509941e+04  4.141264e+04  5.200000e+02
# floors         21597.0  1.494096e+00  5.396828e-01  1.000000e+00
# waterfront     21597.0  7.547345e-03  8.654900e-02  0.000000e+00
# view           21597.0  2.342918e-01  7.663898e-01  0.000000e+00
# condition      21597.0  3.409825e+00  6.505456e-01  1.000000e+00
# grade          21597.0  7.657915e+00  1.173200e+00  3.000000e+00
# sqft_above     21597.0  1.788597e+03  8.277598e+02  3.700000e+02
# sqft_basement  21597.0  2.917250e+02  4.426678e+02  0.000000e+00
# ...

# %% [markdown]
# ### Données Manquantes

# %%
df.isnull() #Affichage des données manquantes
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# ...      ...    ...    ...       ...        ...          ...       ...
# 21592  False  False  False     False      False        False     False
# 21593  False  False  False     False      False        False     False
# 21594  False  False  False     False      False        False     False
# 21595  False  False  False     False      False        False     False
# 21596  False  False  False     False      False        False     False
#
#        floors  waterfront   view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
df.isnull().sum() # Comptage des valeurs manquantes
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %% [markdown]
# On peut dire alors qu'il n'ya pas des valeurs manquantes dans notre dataset

# %%
# Visualisation de la distribution des prix
plt.figure(figsize=(15,11))
sns.displot(df['price']);

# %%
#Comptage des nombres de chambres dans 
plt.figure(figsize=(12,8))
sns.countplot(x=df['bedrooms']);

# %%
# VIsualisation en nuage des points: le rapport entre le prix et la surface habitable
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='sqft_living',data=df);

# %%
# VIsualisation en nuage des points: le rapport entre le prix et la nombres des chambres
plt.figure(figsize=(12,8))
sns.scatterplot(x='bedrooms',y='price',data=df);

# %%
# VIsualisation en boîte à moustache: la distribution des prix par rapport aux nombres des chambres
plt.figure(figsize=(12,8))
sns.boxplot(x='bedrooms',y='price',data=df);

# %% [markdown]
# ### Propriétés géographiques

# %%
# Visualisation en nuage des points: le rapport entre le prix et la longitudianal
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='long',data=df);

# %%
# Visualisation en nuage des points: le rapport entre le prix et la latitude
plt.figure(figsize=(12,8))
sns.scatterplot(x='price',y='lat',data=df);

# %%
# Visualisation en nuage des points: le rapport entre la longitude et latitude
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=df,hue='price',palette='magma_r');

# %%
# Visualisation en boîte à moustache: la distrtibution de la qualiter par rapport aux prix
plt.figure(figsize=(12,8))
sns.boxplot(x='grade',y='price',data=df,palette='magma_r');

# %%
# Visualisation en boîte à moustache: la distrtibution du prix par rapport aux Vue de la mer
plt.figure(figsize=(12,8))
sns.boxplot(x='waterfront',y='price',data=df);

# %% [markdown]
# ## Triage des prix

# %% [markdown]
# ### Ordre decroissante

# %%
# Affichage des 20 appartement le plus chère
df.sort_values('price',ascending=False).head(20)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 7245   6762700020  10/13/2014  7700000.0         6       8.00        12050
# 3910   9808700762   6/11/2014  7060000.0         5       4.50        10040
# 9245   9208900037   9/19/2014  6890000.0         6       7.75         9890
# 4407   2470100110    8/4/2014  5570000.0         5       5.75         9200
# 1446   8907500070   4/13/2015  5350000.0         5       5.00         8000
# 1313   7558700030   4/13/2015  5300000.0         6       6.00         7390
# 1162   1247600105  10/20/2014  5110000.0         5       5.25         8010
# 8085   1924059029   6/17/2014  4670000.0         5       6.75         9640
# 2624   7738500731   8/15/2014  4500000.0         5       5.50         6640
# 8629   3835500195   6/18/2014  4490000.0         4       3.00         6430
# 12358  6065300370    5/6/2015  4210000.0         5       6.00         7440
# ...

# %%
top_20_appart=df.sort_values('price',ascending=False).head(20)

# %%
# Proprieté geographique des 20 appartements les plus chère
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=non_top_1_perc,hue='price',palette='magma');

# %% [markdown]
# ### Ordre croissante

# %%
# Affichage des 15 appartement à faible prix
df.sort_values('price',ascending=True).head(20)
# Out:
#                id        date    price  bedrooms  bathrooms  sqft_living  \
# 15279    40000362    5/6/2014  78000.0         2       1.00          780
# 465    8658300340   5/23/2014  80000.0         1       0.75          430
# 16184  3028200080   3/24/2015  81000.0         2       1.00          730
# 8267   3883800011   11/5/2014  82000.0         3       1.00          860
# 2139   1623049041    5/8/2014  82500.0         2       1.00          520
# 18453  7999600180   5/29/2014  83000.0         2       1.00          900
# 3763   1523049188   4/30/2015  84000.0         2       1.00          700
# 10242  2422049104   9/15/2014  85000.0         2       1.00          830
# 16700  1322049150    3/5/2015  85000.0         2       1.00          910
# 13743  1788900230   7/22/2014  86500.0         3       1.00          840
# 5860   9320900420  10/14/2014  89000.0         3       1.00          900
# 3106   1721801591   2/19/2015  89950.0         1       1.00          570
# ...

# %%
top_20_lowPrice_appart=df.sort_values('price',ascending=True).head(20)

# %%
# Proprieté geographique des 20 appartements à faible prix
plt.figure(figsize=(12,8))
sns.scatterplot(x='long',y='lat',data=top_20_lowPrice_appart,hue='price',palette='magma');
